# %% [markdown]
# <a href="https://colab.research.google.com/github/stavco9/textretrieval-final-project/blob/main/LightGBMRankingSearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================================
# Install Required Packages
# ============================================================================

import sys
import subprocess
import os

print("Installing required packages...")

# Install Java 21 (required for Pyserini/Anserini)
# Use shell commands for Colab
print("Installing Java 21 (required for Pyserini)...")
# !apt-get update -qq
# !apt-get install -y -qq openjdk-21-jdk > /dev/null

# Set Java 21 environment variables
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-21-openjdk-amd64"
os.environ["PATH"] = f"{os.environ['JAVA_HOME']}/bin:{os.environ['PATH']}"

# Verify Java version
java_version = subprocess.check_output(["java", "-version"], stderr=subprocess.STDOUT, text=True)
print(f"✅ Java installed: {java_version.split()[2] if len(java_version.split()) > 2 else 'Java 21'}")

# IMPORTANT: Reinstall pyserini to ensure it picks up Java 21
# This is necessary because pyjnius initializes JVM on first import
print("Reinstalling Pyserini to use Java 21...")
subprocess.check_call([sys.executable, "-m", "pip", "uninstall", "-y", "pyserini"])
subprocess.check_call([sys.executable, "-m", "pip", "install", "pyserini"])
print("✅ Pyserini reinstalled with Java 21")

# Install LightGBM
print("Installing LightGBM...")
subprocess.check_call([sys.executable, "-m", "pip", "install", "lightgbm"])
print("✅ LightGBM installed")

print("\n✅ All packages installed successfully!")
print("\n⚠️  IMPORTANT: If you get Java version errors, restart the runtime:")
print("   Runtime → Restart runtime (or press Ctrl+M .)")
print("   Then run this cell again, then continue with the next cells.")
# Out:
# Installing required packages...
# Installing Java 21 (required for Pyserini)...
# ✅ Java installed: "21.0.9"
# Installing Pyserini...
# sh: apt-get: command not found
# sh: apt-get: command not found
# Requirement already satisfied: pyserini in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (0.36.0)
# Requirement already satisfied: Cython>=0.29.21 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pyserini) (3.2.0)
# Requirement already satisfied: numpy>=1.18.1 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pyserini) (2.3.4)
# Requirement already satisfied: pandas>=1.4.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pyserini) (2.3.3)
# Requirement already satisfied: pyjnius>=1.4.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pyserini) (1.7.0)
# Requirement already satisfied: scikit-learn>=0.22.1 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pyserini) (1.7.2)
# Requirement already satisfied: scipy>=1.4.1 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pyserini) (1.16.3)
# Requirement already satisfied: tqdm in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pyserini) (4.67.1)
# Requirement already satisfied: transformers>=4.6.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pyserini) (4.57.1)
# Requirement already satisfied: sentencepiece>=0.1.95 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pyserini) (0.2.1)
# Requirement already satisfied: nmslib>=2.0.6 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pyserini) (2.1.2)
# Requirement already satisfied: onnxruntime>=1.8.1 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pyserini) (1.23.2)
# Requirement already satisfied: lightgbm>=3.3.2 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pyserini) (4.6.0)
# Requirement already satisfied: spacy>=3.2.1 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pyserini) (3.8.11)
# Requirement already satisfied: pyyaml in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pyserini) (6.0.3)
# Requirement already satisfied: openai>=1.0.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pyserini) (2.7.1)
# Requirement already satisfied: tiktoken>=0.4.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pyserini) (0.12.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pyserini) (22.0.0)
# Requirement already satisfied: pillow>=10.2.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pyserini) (12.0.0)
# Requirement already satisfied: pybind11>=2.11.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pyserini) (3.0.1)
# Requirement already satisfied: coloredlogs in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from onnxruntime>=1.8.1->pyserini) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from onnxruntime>=1.8.1->pyserini) (25.9.23)
# Requirement already satisfied: packaging in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from onnxruntime>=1.8.1->pyserini) (25.0)
# Requirement already satisfied: protobuf in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from onnxruntime>=1.8.1->pyserini) (6.33.0)
# Requirement already satisfied: sympy in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from onnxruntime>=1.8.1->pyserini) (1.14.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from openai>=1.0.0->pyserini) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from openai>=1.0.0->pyserini) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from openai>=1.0.0->pyserini) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from openai>=1.0.0->pyserini) (0.11.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from openai>=1.0.0->pyserini) (2.12.4)
# Requirement already satisfied: sniffio in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from openai>=1.0.0->pyserini) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from openai>=1.0.0->pyserini) (4.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pandas>=1.4.0->pyserini) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pandas>=1.4.0->pyserini) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pandas>=1.4.0->pyserini) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from scikit-learn>=0.22.1->pyserini) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from scikit-learn>=0.22.1->pyserini) (3.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from spacy>=3.2.1->pyserini) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from spacy>=3.2.1->pyserini) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from spacy>=3.2.1->pyserini) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from spacy>=3.2.1->pyserini) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from spacy>=3.2.1->pyserini) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from spacy>=3.2.1->pyserini) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from spacy>=3.2.1->pyserini) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from spacy>=3.2.1->pyserini) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from spacy>=3.2.1->pyserini) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from spacy>=3.2.1->pyserini) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from spacy>=3.2.1->pyserini) (0.20.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from spacy>=3.2.1->pyserini) (2.32.5)
# Requirement already satisfied: jinja2 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from spacy>=3.2.1->pyserini) (3.1.6)
# Requirement already satisfied: setuptools in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from spacy>=3.2.1->pyserini) (80.9.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from tiktoken>=0.4.0->pyserini) (2025.11.3)
# Requirement already satisfied: filelock in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from transformers>=4.6.0->pyserini) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from transformers>=4.6.0->pyserini) (0.36.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from transformers>=4.6.0->pyserini) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from transformers>=4.6.0->pyserini) (0.6.2)
# Requirement already satisfied: idna>=2.8 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai>=1.0.0->pyserini) (3.11)
# Requirement already satisfied: certifi in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai>=1.0.0->pyserini) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai>=1.0.0->pyserini) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.0.0->pyserini) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.6.0->pyserini) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.6.0->pyserini) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai>=1.0.0->pyserini) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai>=1.0.0->pyserini) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai>=1.0.0->pyserini) (0.4.2)
# Requirement already satisfied: six>=1.5 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->pyserini) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2.1->pyserini) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2.1->pyserini) (2.5.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from thinc<8.4.0,>=8.3.4->spacy>=3.2.1->pyserini) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from thinc<8.4.0,>=8.3.4->spacy>=3.2.1->pyserini) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from typer-slim<1.0.0,>=0.3.0->spacy>=3.2.1->pyserini) (8.3.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from weasel<0.5.0,>=0.4.2->spacy>=3.2.1->pyserini) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from weasel<0.5.0,>=0.4.2->spacy>=3.2.1->pyserini) (7.5.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from coloredlogs->onnxruntime>=1.8.1->pyserini) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from jinja2->spacy>=3.2.1->pyserini) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from sympy->onnxruntime>=1.8.1->pyserini) (1.3.0)
# Requirement already satisfied: wrapt in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy>=3.2.1->pyserini) (2.0.1)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# ✅ Pyserini installed
# Installing LightGBM...
# Requirement already satisfied: lightgbm in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from lightgbm) (2.3.4)
# Requirement already satisfied: scipy in /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages (from lightgbm) (1.16.3)
# ✅ LightGBM installed
#
# ✅ All packages installed successfully!
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# ============================================================================
# Setup and Imports
# ============================================================================

import numpy as np
import pandas as pd
import lightgbm as lgb
import os
import sys
import subprocess
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from google.colab import files

# Ensure Java 21 environment is set (required for Pyserini)
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-21-openjdk-amd64"
os.environ["PATH"] = f"{os.environ['JAVA_HOME']}/bin:{os.environ['PATH']}"

# Verify Java version before importing pyserini
try:
    java_version_output = subprocess.check_output(
        ["java", "-version"], 
        stderr=subprocess.STDOUT, 
        text=True
    )
    # Check if Java 21 is in the output
    if "21" not in java_version_output and "openjdk version \"21" not in java_version_output:
        print("⚠️  WARNING: Java 21 may not be active.")
        print("   If you get Java version errors, please:")
        print("   1. Go to: Runtime → Restart runtime")
        print("   2. Run the installation cell (Cell 1) again")
        print("   3. Then run this cell again")
    else:
        print(f"✅ Java 21 is active: {java_version_output.split()[2] if len(java_version_output.split()) > 2 else 'Java 21'}")
except Exception as e:
    print(f"⚠️  Could not verify Java version: {e}")

# Import pyserini (this will initialize JVM - must use Java 21)
try:
    import pyserini
    print("✅ Pyserini imported successfully")
except Exception as e:
    if "UnsupportedClassVersionError" in str(e) or "class file version 65.0" in str(e):
        print("\n❌ Java Version Error!")
        print("   Pyserini requires Java 21, but an older Java version is being used.")
        print("\n   SOLUTION:")
        print("   1. Go to: Runtime → Restart runtime (or press Ctrl+M .)")
        print("   2. Run Cell 1 (Install Required Packages) again")
        print("   3. Then run this cell again")
        print("\n   This is necessary because pyjnius initializes the JVM on first import,")
        print("   and it needs to be initialized with Java 21 from the start.")
        raise
    else:
        raise

import lightgbm

print("\n📁 Required files (relative to text-retrieval/ex4/):")
print("   - rank.py")
print("   - files/qrels_50_Queries")
print("   - files/queriesROBUST.txt")
print("\n💡 Note: After cloning the repo, we'll change to text-retrieval/ex4/ directory")
print("\n📦 Index: Using pyserini prebuilt index 'robust04' (no local index needed)")
print("   The index will be automatically downloaded on first use.")
print("\n" + "="*60)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[9], line 7
#       5 import numpy as np
#       6 import pandas as pd
# ----> 7 import lightgbm as lgb
#       8 import os
#       9 import sys
#
# File ~/personal/text-retrieval/venv/lib/python3.13/site-packages/lightgbm/__init__.py:11
#       7 from pathlib import Path
#       9 # .basic is intentionally loaded as early as possible, to dlopen() lib_lightgbm.{dll,dylib,so}
#      10 # and its dependencies as early as possible
# ---> 11 from .basic import Booster, Dataset, Sequence, register_logger
#      12 from .callback import EarlyStopException, early_stopping, log_evaluation, record_evaluation, reset_parameter
#      13 from .engine import CVBooster, cv, train
#
# File ~/personal/text-retrieval/venv/lib/python3.13/site-packages/lightgbm/basic.py:9
#       2 """Wrapper for C API of LightGBM."""
#       4 # This import causes lib_lightgbm.{dll,dylib,so} to be loaded.
#       5 # It's intentionally done here, as early as possible, to avoid issues like
#       6 # "libgomp.so.1: cannot allocate memory in static TLS block" on aarch64 Linux.
#       7 #
#       8 # For details, see the "cannot allocate memory in static TLS block" entry in docs/FAQ.rst.
# ----> 9 from .libpath import _LIB  # isort: skip
#      11 import abc
#      12 import ctypes
#
# File ~/personal/text-retrieval/venv/lib/python3.13/site-packages/lightgbm/libpath.py:49
#      47     _LIB = Mock(ctypes.CDLL)  # type: ignore
#      48 else:
# ---> 49     _LIB = ctypes.cdll.LoadLibrary(_find_lib_path()[0])
#
# File /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ctypes/__init__.py:471, in LibraryLoader.LoadLibrary(self, name)
#     470 def LoadLibrary(self, name):
# --> 471     return self._dlltype(name)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ctypes/__init__.py:390, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     387 self._FuncPtr = _FuncPtr
#     389 if handle is None:
# --> 390     self._handle = _dlopen(self._name, mode)
#     391 else:
#     392     self._handle = handle
#
# OSError: dlopen(/Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages/lightgbm/lib/lib_lightgbm.dylib, 0x0006): Library not loaded: @rpath/libomp.dylib
#   Referenced from: <D44045CD-B874-3A27-9A61-F131D99AACE4> /Users/amitshmoshkin/personal/text-retrieval/venv/lib/python3.13/site-packages/lightgbm/lib/lib_lightgbm.dylib
#   Reason: tried: '/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/opt/local/lib/libomp/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/local/lib/libomp/libomp.dylib' (no such file), '/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/opt/local/lib/libomp/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/local/lib/libomp/libomp.dylib' (no such file), '/opt/homebrew/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/lib/libomp.dylib' (no such file), '/opt/homebrew/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/lib/libomp.dylib' (no such file)

# %%
# !rm -rf text-retrieval
# !git clone https://github.com/shmoshkin/text-retrieval.git

# Change to the ex4 directory
import os
os.chdir('text-retrieval/ex4')
print(f"✅ Changed directory to: {os.getcwd()}")

# %%
# ============================================================================
# File Upload and Verification
# ============================================================================

print("📤 File Upload Helper")
print("="*60)
print("\nTo upload files:")
print("1. Use the Files sidebar (📁 icon) to drag and drop files")
print("2. Or uncomment files.upload() below to upload interactively")
print("3. Or mount Google Drive and copy files from Drive")
print("\n" + "="*60)

# Uncomment the line below to upload files interactively
# files.upload()

# Verify critical files
print("\n🔍 Checking for required files...")
required_files = [
    'rank.py',
    'files/qrels_50_Queries',
    'files/queriesROBUST.txt'
]

all_files_exist = True
for file_path in required_files:
    if os.path.exists(file_path):
        print(f"✅ {file_path}")
    else:
        print(f"❌ {file_path} - MISSING!")
        all_files_exist = False

print("\n" + "="*60)
if all_files_exist:
    print("✅ All required files found! Ready to proceed.")
else:
    print("⚠️  Some files are missing. Please upload them before continuing.")

# %%
# ============================================================================
# CONFIGURATION: Choose which methods to run
# ============================================================================

# Set to True to run each method
RUN_RM3 = True      # Run 1: RM3 (Relevance Model 3)
RUN_VECTOR = True   # Run 2: Vector-based (TF-IDF Cosine Similarity)
RUN_LIGHTGBM = True # Run 3: LightGBM Learning-to-Rank

# Paths (using local repository from Colab)
# After git clone and os.chdir('text-retrieval/ex4'), we're in the ex4 directory
BASE_DIR = "."  # Current directory (text-retrieval/ex4)
FILES_DIR = f"{BASE_DIR}/files"
RESULTS_DIR = f"{BASE_DIR}/results"

# Verify we're in the right directory
print(f"📁 Working directory: {os.getcwd()}")
print(f"📁 Base directory: {BASE_DIR}")
print(f"📁 Files directory: {FILES_DIR}")
print(f"📁 Results directory: {RESULTS_DIR}")

# Input files
RELEVANT_FLAGS_PATH = f'{FILES_DIR}/qrels_50_Queries'

# Baseline ranking file for LightGBM (will try to find automatically if not specified)
# Options: 'run_10_bm25.res', 'run_1_rm3.res', 'run_2_vector.res', or None for auto-detect
BASELINE_RANKING_FILE = None  # Set to None to auto-detect, or specify path

# Output files
OUTPUT_RUN1 = f'{RESULTS_DIR}/run_1_rm3.res'
OUTPUT_RUN2 = f'{RESULTS_DIR}/run_2_vector.res'
OUTPUT_RUN3 = f'{RESULTS_DIR}/run_3_lightgbm.res'

# Auto-detect baseline file if not specified
if BASELINE_RANKING_FILE is None:
    # Try to find an existing baseline file
    possible_baselines = [
        f'{RESULTS_DIR}/run_10_bm25.res',
        f'{RESULTS_DIR}/run_1_rm3.res',
        f'{RESULTS_DIR}/run_2_vector.res'
    ]
    for baseline in possible_baselines:
        if os.path.exists(baseline):
            RANKED_RESULTS_PATH = baseline
            print(f"✅ Auto-detected baseline: {baseline}")
            break
    else:
        RANKED_RESULTS_PATH = f'{RESULTS_DIR}/run_10_bm25.res'  # Default
        print(f"⚠️  No baseline found, will use: {RANKED_RESULTS_PATH}")
else:
    RANKED_RESULTS_PATH = BASELINE_RANKING_FILE

print("\nConfiguration:")
print(f"  Run RM3: {RUN_RM3}")
print(f"  Run Vector: {RUN_VECTOR}")
print(f"  Run LightGBM: {RUN_LIGHTGBM}")
print(f"  Base directory: {BASE_DIR}")
print(f"  Baseline for LightGBM: {RANKED_RESULTS_PATH}")

# %%
# ============================================================================
# Run Baseline Ranking Methods (RM3 and Vector-based)
# ============================================================================

if RUN_RM3 or RUN_VECTOR or (RUN_LIGHTGBM and not os.path.exists(RANKED_RESULTS_PATH)):
    # Import ranking functions
    import sys
    sys.path.append(BASE_DIR)
    
    from rank import rank_documents, rank_documents_vector
    
    # Check if we need to generate BM25 for LightGBM baseline
    if RUN_LIGHTGBM and not os.path.exists(RANKED_RESULTS_PATH):
        print("\n" + "="*60)
        print("Generating BM25 baseline for LightGBM (Run 10)")
        print("="*60)
        rank_documents(run_number=10, method="bm25", top_k=1000)
        # Update path after generation
        RANKED_RESULTS_PATH = f'{RESULTS_DIR}/run_10_bm25.res'
        print(f"✅ Baseline generated: {RANKED_RESULTS_PATH}")
    
    if RUN_RM3:
        print("\n" + "="*60)
        print("Running RM3 Method (Run 1)")
        print("="*60)
        rank_documents(run_number=1, method="rm3", top_k=1000)
    
    if RUN_VECTOR:
        print("\n" + "="*60)
        print("Running Vector-based Method (Run 2)")
        print("="*60)
        rank_documents_vector(run_number=2, top_k=1000)
    
    print("\n✅ Baseline methods completed!")
else:
    print("Skipping baseline methods (RM3 and Vector)")

# %%
# ============================================================================
# Load Data for LightGBM Training
# ============================================================================

if RUN_LIGHTGBM:
    # Check if baseline results exist
    if not os.path.exists(RANKED_RESULTS_PATH):
        print(f"⚠️  Warning: Baseline results not found at {RANKED_RESULTS_PATH}")
        print("   Please run RM3 or BM25 first to generate baseline rankings.")
        print("   Or update RANKED_RESULTS_PATH to point to an existing .res file.")
        RUN_LIGHTGBM = False
    else:
        relevant_flags_list = []
        ranked_results_list = []

        print(f"Loading ranked results from: {RANKED_RESULTS_PATH}")
        with open(RANKED_RESULTS_PATH, 'r') as f:
            ranked_results = f.readlines()

        for result in ranked_results:
            ranked_results_list.append({
                'query_id': result.split()[0],
                'doc_id': result.split()[2],
                'rank': result.split()[3],
                'score': result.split()[4]
            })

        print(f"Loading relevance judgments from: {RELEVANT_FLAGS_PATH}")
        with open(RELEVANT_FLAGS_PATH, 'r') as f:
            relevant_flags = f.readlines()

        for relevant in relevant_flags:
            relevant_flags_list.append({
                'query_id': relevant.split()[0],
                'doc_id': relevant.split()[2],
                'relevance': relevant.split()[3]
            })
        
        print(f"✅ Loaded {len(ranked_results_list)} ranked results")
        print(f"✅ Loaded {len(relevant_flags_list)} relevance judgments")
else:
    print("Skipping LightGBM (not enabled in configuration)")

# %%
if RUN_LIGHTGBM:
    ranked_results_df = pd.DataFrame.from_records(ranked_results_list)
    relevant_flags_df = pd.DataFrame.from_records(relevant_flags_list)
    
    print(f"Ranked results: {len(ranked_results_df)} rows")
    print(f"Relevance flags: {len(relevant_flags_df)} rows")
else:
    print("Skipping data preparation (LightGBM not enabled)")

# %%
if RUN_LIGHTGBM:
    df = pd.merge(
        left=ranked_results_df,
        right=relevant_flags_df,
        how='left',
        left_on=['query_id', 'doc_id'],
        right_on=['query_id', 'doc_id'],
    ).drop_duplicates()
    
    print(f"Merged dataframe: {len(df)} rows")
    print(f"Unique queries: {df['query_id'].nunique()}")
else:
    print("Skipping merge (LightGBM not enabled)")

# %%
if RUN_LIGHTGBM:
    df['relevance'] = df['relevance'].fillna(0)
    print(f"Relevance distribution:")
    print(df['relevance'].value_counts())
else:
    print("Skipping relevance fill (LightGBM not enabled)")

# %%
if RUN_LIGHTGBM:
    df['query_id'] = df['query_id'].astype(int)
    df['relevance'] = df['relevance'].astype(int)
    df['rank'] = df['rank'].astype(int)
    df['score'] = df['score'].astype(float)
    
    print("✅ Data types converted")
    print(df.dtypes)
else:
    print("Skipping type conversion (LightGBM not enabled)")

# %%
if RUN_LIGHTGBM:
    N_labeled = 50
    N_max = 10000

    train_queries = []

    all_queries = df['query_id'].unique()
    print(f"Total unique queries: {len(all_queries)}")
    print(f"Using first {N_labeled} queries for training")
    
    for query_id in all_queries[:N_labeled]:
        train_queries.append(df.loc[(df['query_id'] == query_id)][:int(N_max/N_labeled)])
    
    print(f"Prepared {len(train_queries)} training query sets")
else:
    print("Skipping training data preparation (LightGBM not enabled)")

# %%
if RUN_LIGHTGBM:
    df_labeled = pd.concat(train_queries)
    print(f"Combined training data: {len(df_labeled)} rows")
    print(f"Unique queries in training: {df_labeled['query_id'].nunique()}")
    df_labeled.head()
else:
    print("Skipping (LightGBM not enabled)")
# Out:
#        query_id            doc_id  rank   score  relevance
# 0           301       FBIS4-41991     1  8.2814          0
# 1           301       FBIS4-38364     2  7.9861          1
# 2           301       FBIS3-19646     3  7.9419          1
# 3           301       FBIS3-21961     4  7.9419          1
# 4           301       FBIS4-19535     5  7.9335          0
# ...         ...               ...   ...     ...        ...
# 44917       350        FT943-7679   196  5.5832          0
# 44918       350  FR940610-1-00047   197  5.5829          0
# 44919       350       FBIS3-59008   198  5.5788          0
# 44920       350     LA030889-0016   199  5.5751          0
# 44921       350     LA101190-0094   200  5.5729          0
#
# [9442 rows x 5 columns]

# %%
if RUN_LIGHTGBM:
    df_labeled_train = df_labeled[:int(len(df_labeled)*0.8)]
    df_labeled_val = df_labeled[int(len(df_labeled)*0.8):]

    qids_train = df_labeled_train.groupby("query_id")["query_id"].count().to_numpy()
    X_train = df_labeled_train.drop(['doc_id', 'query_id', 'relevance'], axis=1)
    y_train = df_labeled_train['relevance']

    qids_val = df_labeled_val.groupby("query_id")["query_id"].count().to_numpy()
    X_val = df_labeled_val.drop(['doc_id', 'query_id', 'relevance'], axis=1)
    y_val = df_labeled_val['relevance']
    
    print(f"Training set: {len(X_train)} samples, {len(qids_train)} queries")
    print(f"Validation set: {len(X_val)} samples, {len(qids_val)} queries")
    print(f"Features: {list(X_train.columns)}")
else:
    print("Skipping train/val split (LightGBM not enabled)")

# %%
if RUN_LIGHTGBM:
    gbm = lgb.LGBMRanker(
        boosting_type="gbdt",
        learning_rate=0.1,
        n_estimators=100,
        objective="lambdarank",
        metric="ndcg"
    )
    print("✅ LightGBM Ranker initialized")
else:
    print("Skipping LightGBM initialization (not enabled)")

# %%
if RUN_LIGHTGBM:
    print("Training LightGBM model...")
    gbm.fit(
        X=X_train,
        y=y_train,
        group=qids_train,
        eval_set=[(X_val, y_val)],
        eval_group=[qids_val],
        eval_at=10
    )
    print("✅ Model training completed")
else:
    print("Skipping model training (LightGBM not enabled)")
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000333 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 456
# [LightGBM] [Info] Number of data points in the train set: 7553, number of used features: 2
# LGBMRanker(metric='ndcg', objective='lambdarank')

# %%
if RUN_LIGHTGBM:
    print("Generating predictions for all queries...")
    results_out = []

    for query_id in tqdm(all_queries, desc="Predicting", unit="query"):
        df_test = df.loc[(df['query_id'] == query_id)][:1000]
        if len(df_test) == 0:
            continue
            
        X_test = df_test.drop(['doc_id', 'query_id', 'relevance'], axis=1)

        test_pred = gbm.predict(X_test)
        X_test = X_test.copy()
        X_test["new_score"] = test_pred
        X_test = X_test.sort_values("new_score", ascending=False)
        X_test.insert(0, 'new_rank', range(1, 1 + len(X_test)))

        # Map back to doc_ids
        for i, row in X_test.iterrows():
            original_rank = int(row['rank'])
            doc_id = df_test.loc[df_test['rank'] == original_rank, 'doc_id'].iloc[0]
            new_rank = int(row['new_rank'])
            new_score = round(row['new_score'], 4)
            results_out.append(f"{query_id} Q0 {doc_id} {new_rank} {new_score} run3")
    
    print(f"✅ Generated {len(results_out)} predictions")
else:
    print("Skipping predictions (LightGBM not enabled)")

# %%
if RUN_LIGHTGBM:
    os.makedirs(RESULTS_DIR, exist_ok=True)
    
    with open(OUTPUT_RUN3, 'w') as f:
        for line in results_out:
            f.write(f"{line}\n")
    
    print(f"✅ Results saved to: {OUTPUT_RUN3}")
    print(f"   Total lines: {len(results_out)}")
    
    # Download if in Colab
    if IN_COLAB and files:
        files.download(OUTPUT_RUN3)
        print("✅ File downloaded")
else:
    print("Skipping save (LightGBM not enabled)")

# %%
# ============================================================================
# Summary
# ============================================================================

print("\n" + "="*60)
print("RUN SUMMARY")
print("="*60)

if RUN_RM3:
    if os.path.exists(OUTPUT_RUN1):
        size = os.path.getsize(OUTPUT_RUN1) / (1024*1024)  # MB
        print(f"✅ Run 1 (RM3): {OUTPUT_RUN1} ({size:.2f} MB)")
    else:
        print(f"❌ Run 1 (RM3): Not generated")

if RUN_VECTOR:
    if os.path.exists(OUTPUT_RUN2):
        size = os.path.getsize(OUTPUT_RUN2) / (1024*1024)  # MB
        print(f"✅ Run 2 (Vector): {OUTPUT_RUN2} ({size:.2f} MB)")
    else:
        print(f"❌ Run 2 (Vector): Not generated")

if RUN_LIGHTGBM:
    if os.path.exists(OUTPUT_RUN3):
        size = os.path.getsize(OUTPUT_RUN3) / (1024*1024)  # MB
        print(f"✅ Run 3 (LightGBM): {OUTPUT_RUN3} ({size:.2f} MB)")
    else:
        print(f"❌ Run 3 (LightGBM): Not generated")

print("="*60)

# %%
# ============================================================================
# Evaluate Results - MAP Only
# ============================================================================

import subprocess
import re
import os
from pathlib import Path

# Paths
QRELS_PATH = './files/qrels_50_Queries'
RESULTS_DIR = './results'

# Define runs to evaluate
runs_to_evaluate = [
    ('run_1_rm3.res', 'run_1_rm3_eval.txt', 'RM3'),
    ('run_2_vector.res', 'run_2_vector_eval.txt', 'Vector-based'),
    ('run_3_lightgbm.res', 'run_3_lightgbm_eval.txt', 'LightGBM')
]

print("="*60)
print("EVALUATION RESULTS - MAP (Mean Average Precision)")
print("="*60)
print()

# Function to find trec_eval JAR file
def find_trec_eval_jar():
    """Find the trec_eval JAR file used by pyserini"""
    # Try cache directory (most reliable)
    cache_dir = Path.home() / '.cache' / 'pyserini' / 'eval'
    jar_file = cache_dir / 'jtreceval-0.0.5-jar-with-dependencies.jar'
    if jar_file.exists():
        return str(jar_file)
    
    # Try pyserini package directory
    try:
        import pyserini
        pyserini_dir = Path(pyserini.__file__).parent
        jar_file = pyserini_dir / 'resources' / 'jars' / 'jtreceval-0.0.5-jar-with-dependencies.jar'
        if jar_file.exists():
            return str(jar_file)
    except:
        pass
    
    return None

# Function to evaluate using JAR directly
def evaluate_with_jar(jar_path, qrels_path, run_path, output_path):
    """Evaluate using trec_eval JAR directly via Java"""
    cmd = [
        'java', '-jar', jar_path,
        '-q', qrels_path,
        run_path
    ]
    try:
        output = subprocess.check_output(cmd, stderr=subprocess.STDOUT, text=True, timeout=60)
        # Save output to file
        with open(output_path, 'w') as f:
            f.write(output)
        return output
    except subprocess.TimeoutExpired:
        return None
    except Exception as e:
        return None

# Function to parse evaluation file
def parse_eval_file(eval_file_path):
    """Parse an existing evaluation file to extract MAP"""
    try:
        with open(eval_file_path, 'r') as f:
            content = f.read()
        map_match = re.search(r'map\s+all\s+([\d.]+)', content)
        if map_match:
            return float(map_match.group(1))
    except:
        pass
    return None

# Step 1: Try to find JAR file
jar_path = find_trec_eval_jar()
if jar_path:
    print(f"✅ Found trec_eval JAR: {jar_path}")
else:
    print("⚠️  Could not find trec_eval JAR file")
    print("   Will try to parse existing eval files if they exist")

print()

# Step 2: Evaluate each run
results = {}

for run_file, eval_file, method_name in runs_to_evaluate:
    run_path = os.path.join(RESULTS_DIR, run_file)
    eval_path = os.path.join(RESULTS_DIR, eval_file)
    
    # Check if .res file exists
    if not os.path.exists(run_path):
        print(f"⚠️  {method_name:20s} ({run_file}): File not found")
        results[method_name] = None
        continue
    
    map_score = None
    
    # Try method 1: Check if evaluation file already exists
    if os.path.exists(eval_path):
        map_score = parse_eval_file(eval_path)
        if map_score is not None:
            results[method_name] = map_score
            print(f"✅ {method_name:20s} ({run_file}): MAP = {map_score:.4f} (from existing file)")
            continue
    
    # Try method 2: Use JAR directly to evaluate
    if jar_path and os.path.exists(jar_path):
        print(f"   Evaluating {method_name}...", end=' ')
        output = evaluate_with_jar(jar_path, QRELS_PATH, run_path, eval_path)
        if output:
            map_score = parse_eval_file(eval_path)
            if map_score is not None:
                results[method_name] = map_score
                print(f"✅ MAP = {map_score:.4f}")
                continue
        print("❌ Failed")
    
    # Try method 3: Run trec_eval.sh (may fail on Python 3.12)
    if map_score is None:
        try:
            # Try running just the specific command from the script
            cmd = ['python', '-m', 'pyserini.eval.trec_eval', '-q', QRELS_PATH, run_path]
            output = subprocess.check_output(cmd, stderr=subprocess.STDOUT, text=True, timeout=60)
            # Save output
            with open(eval_path, 'w') as f:
                f.write(output)
            map_score = parse_eval_file(eval_path)
            if map_score is not None:
                results[method_name] = map_score
                print(f"✅ {method_name:20s} ({run_file}): MAP = {map_score:.4f}")
                continue
        except:
            pass
    
    # If all methods failed
    if map_score is None:
        print(f"❌ {method_name:20s} ({run_file}): Could not evaluate")
        results[method_name] = None

print()
print("="*60)
print("SUMMARY")
print("="*60)

# Sort by MAP score (descending)
sorted_results = sorted(
    [(name, score) for name, score in results.items() if score is not None],
    key=lambda x: x[1],
    reverse=True
)

if sorted_results:
    print("\nRanking by MAP:")
    for rank, (method_name, map_score) in enumerate(sorted_results, 1):
        print(f"  {rank}. {method_name:20s}: {map_score:.4f}")
    
    # Find best
    best_method, best_map = sorted_results[0]
    print(f"\n🏆 Best Method: {best_method} (MAP = {best_map:.4f})")
else:
    print("\n❌ No valid results found")
    print("\n💡 Troubleshooting:")
    print("   1. Make sure .res files exist in ./results/")
    print("   2. Check if trec_eval JAR is available")
    print("   3. You may need to run evaluation manually using:")
    print("      bash trec_eval.sh")

print("="*60)
